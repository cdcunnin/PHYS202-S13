# %%
N,t = loadtxt("radioactivedecay.dat",unpack=True,usecols=[0,1])

# %%
scatter(N,t,marker="*")

# %%
scatter(log(N),log(t))
# Out:
# -c:1: RuntimeWarning: divide by zero encountered in log

# %%
from CurveFitting import *

linleastsquaresfit(N,t)
# Out:
# uncertainty in y = 1.67199826668
# m = -0.549338235294
# b = 6.45691176471
# uncertainty in m: 0.0145749770049
# uncertainty in b: 0.513237901778
# [-0.54933823529411774,
#  6.4569117647058825,
#  0.014574977004943913,
#  0.51323790177787765]

# %%
x = arange(0,3,0.1)

y = (linleastsquaresfit(N,t)[0])*x+(linleastsquaresfit(N,t)[1])

plot(x,y)
scatter(log(N),log(t))
# Out:
# uncertainty in y = 1.67199826668
# m = -0.549338235294
# b = 6.45691176471
# uncertainty in m: 0.0145749770049
# uncertainty in b: 0.513237901778
# uncertainty in y = 1.67199826668
# m = -0.549338235294
# b = 6.45691176471
# uncertainty in m: 0.0145749770049
# uncertainty in b: 0.513237901778
