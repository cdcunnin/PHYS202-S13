# %%
x = arange(-2,2,0.01)

dydx= lambda x,y: x+2*y

def Euler(f, xa, xb, ya, n):
    dx = (xb - xa) / float(n)
    x = xa
    y = ya
    for i in range(n):
        y += dx * f(x, y)
        x += dx
    return x,y

print Euler(dydx,0,1,0,500)
# Out:
# (1.0000000000000007, 1.0899092939672432)

# %%
#A) x=1:

print Euler(dydx,0,1,0,4)[1]
print Euler(dydx,0,1,0,5)[1]
# Out:
# 0.515625
# 0.59456

# %%
#B)

x1 = arange(0.,1.25,0.25)
x2 = arange(0.,1.02,0.2)

y = 0.25*e**(2*x2)-0.5*x2-0.25

plot(x1,Euler(dydx,0,x1,0,4)[1])
plot(x2,Euler(dydx,0,x2,0,5)[1])
plot(x2,y)
